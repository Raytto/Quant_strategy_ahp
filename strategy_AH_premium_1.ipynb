# %%
# 导入tushare
import tushare as ts
import pandas as pd

# %%
ah_k = pd.read_csv(r"data\AH_premium_analysis.csv", encoding="utf-8-sig")
ah_k = ah_k[
    [
        "ts_code_A",
        "ts_code_HK",
        "trade_date",
        "name",
        "p_a_adj",
        "p_hk_adj",
        "hk2cn",
        "AH_premium_adj",
    ]
]
ah_k
# Out:
#         ts_code_A ts_code_HK  trade_date  name    p_a_adj  p_hk_adj     hk2cn  \
# 0       000333.SZ   00300.HK    20240919  美的集团  62.270696     64.25  0.903838
# 1       000333.SZ   00300.HK    20240923  美的集团  64.483748     67.60  0.900349
# 2       000333.SZ   00300.HK    20240924  美的集团  64.903465     70.15  0.903029
# 3       000333.SZ   00300.HK    20240925  美的集团  66.878041     70.70  0.896083
# 4       000333.SZ   00300.HK    20240926  美的集团  70.169001     77.70  0.898161
# ...           ...        ...         ...   ...        ...       ...       ...
# 217021  688331.SH   09995.HK    20250625  荣昌生物  74.350000     67.05  0.912076
# 217022  688331.SH   09995.HK    20250626  荣昌生物  60.700000     59.20  0.913421
# 217023  688331.SH   09995.HK    20250630  荣昌生物  60.500000     54.45  0.912101
# 217024  688331.SH   09995.HK    20250702  荣昌生物  62.790000     55.25  0.913276
# 217025  688331.SH   09995.HK    20250703  荣昌生物  64.440000     58.95  0.913398
#
#         AH_premium_adj
# 0             0.072310
# 1             0.059480
# 2             0.024562
# 3             0.055640
# 4             0.005473
# ...                ...
# 217021        0.215769
# 217022        0.122525
# 217023        0.218188
# 217024        0.244389
# 217025        0.196772
#
# [217026 rows x 8 columns]

# %%
SH300_k = pd.read_csv(r"data\SH300_daily_k.csv", encoding="utf-8-sig")
SH300_k
# Out:
#         ts_code  trade_date      close       open       high        low  \
# 0     000300.SH    20250704  3982.2034  3967.4637  4013.8478  3958.3762
# 1     000300.SH    20250703  3968.0676  3949.3998  3971.6160  3945.1380
# 2     000300.SH    20250702  3943.6849  3943.3232  3952.1378  3929.6956
# 3     000300.SH    20250701  3942.7620  3935.9078  3946.2451  3924.7219
# 4     000300.SH    20250630  3936.0791  3920.3149  3940.3611  3911.6044
# ...         ...         ...        ...        ...        ...        ...
# 3651  000300.SH    20100623  2758.4950  2768.6950  2788.2190  2734.0470
# 3652  000300.SH    20100622  2783.7200  2772.8860  2795.3230  2766.4430
# 3653  000300.SH    20100621  2780.6630  2698.9840  2784.4700  2686.3230
# 3654  000300.SH    20100618  2696.1660  2739.0320  2755.8420  2686.6140
# 3655  000300.SH    20100617  2742.7330  2778.5330  2784.9160  2742.6400
#
#       pre_close   change  pct_chg          vol        amount
# 0     3968.0676  14.1358   0.3562  157197133.0  2.905130e+08
# 1     3943.6849  24.3827   0.6183  141004006.0  2.696096e+08
# 2     3942.7620   0.9229   0.0234  147063062.0  2.466378e+08
# 3     3936.0791   6.6829   0.1698  128959362.0  2.360703e+08
# 4     3921.7578  14.3213   0.3652  145170236.0  2.888214e+08
# ...         ...      ...      ...          ...           ...
# 3651  2783.7200 -25.2250  -0.9062   35600350.0  4.160024e+07
# 3652  2780.6630   3.0570   0.1099   39096052.0  4.520721e+07
# 3653  2696.1660  84.4970   3.1340   55261482.0  6.280919e+07
# 3654  2742.7330 -46.5670  -1.6978   41808344.0  5.025635e+07
# 3655  2758.8660 -16.1330  -0.5848   32612356.0  4.029323e+07
#
# [3656 rows x 11 columns]

# %%
HSI_k = pd.read_csv(r"data\HSI_daily_k.csv", encoding="utf-8-sig")
HSI_k
# Out:
#      ts_code  trade_date      open     close      high       low  pre_close  \
# 0        HSI    20250704  23900.69  23916.06  24068.51  23690.94   24069.94
# 1        HSI    20250703  24234.28  24069.94  24269.14  23920.00   24221.41
# 2        HSI    20250702  24304.31  24221.41  24372.70  24122.57   24072.28
# 3        HSI    20250630  24274.91  24072.28  24274.91  24064.26   24284.15
# 4        HSI    20250627  24451.19  24284.15  24471.53  24194.85   24325.40
# ...      ...         ...       ...       ...       ...       ...        ...
# 3701     HSI    20100621  20571.40  20912.18  20938.33  20571.40   20286.71
# 3702     HSI    20100618  20199.22  20286.71  20315.42  20138.35   20138.40
# 3703     HSI    20100617  20201.81  20138.40  20201.81  20078.59   20062.15
# 3704     HSI    20100615  19998.53  20062.15  20142.10  19970.91   20051.91
# 3705     HSI    20100614  20102.55  20051.91  20102.55  20024.04   19872.38
#
#       change  pct_chg  swing         vol
# 0    -153.88    -0.64   1.57  4021196.00
# 1    -151.47    -0.63   1.44  3594907.00
# 2     149.13     0.62   1.04  4061334.00
# 3    -211.87    -0.87   0.87  3775880.00
# 4     -41.25    -0.17   1.14  4341564.00
# ...      ...      ...    ...         ...
# 3701  625.47     3.08   1.81  3171247.00
# 3702  148.31     0.74   0.88  1413431.00
# 3703   76.25     0.38   0.61  1034863.00
# 3704   10.24     0.05   0.85   996054.69
# 3705  179.53     0.90   0.40   954758.25
#
# [3706 rows x 11 columns]

# %%
IXIC_k = pd.read_csv(r"data\IXIC_daily_k.csv", encoding="utf-8-sig")
IXIC_k
# Out:
#      ts_code  trade_date     open     close      high       low  pre_close  \
# 0       IXIC    20250703      NaN  20601.10  20624.51  20480.22   20393.13
# 1       IXIC    20250702      NaN  20393.13  20397.22  20181.74   20202.89
# 2       IXIC    20250701      NaN  20202.89  20339.05  20105.42   20369.73
# 3       IXIC    20250630      NaN  20369.73  20418.31  20266.36   20273.46
# 4       IXIC    20250627      NaN  20273.46  20311.51  20095.05   20167.91
# ...      ...         ...      ...       ...       ...       ...        ...
# 3783    IXIC    20100618  2308.94   2309.80   2321.99   2301.48    2307.16
# 3784    IXIC    20100617  2316.59   2307.16   2318.27   2288.59    2305.93
# 3785    IXIC    20100616  2293.56   2305.93   2317.75   2290.26    2305.88
# 3786    IXIC    20100615  2256.48   2305.88   2307.98   2256.44    2243.96
# 3787    IXIC    20100614  2263.66   2243.96   2278.96   2242.00    2243.60
#
#       change  pct_chg  swing  vol
# 0     207.97     1.02   0.71  NaN
# 1     190.24     0.94   1.07  NaN
# 2    -166.84    -0.82   1.15  NaN
# 3      96.27     0.47   0.75  NaN
# 4     105.55     0.52   1.07  NaN
# ...      ...      ...    ...  ...
# 3783    2.64     0.11   0.89  NaN
# 3784    1.23     0.05   1.29  NaN
# 3785    0.05     0.00   1.19  NaN
# 3786   61.92     2.76   2.30  NaN
# 3787    0.36     0.02   1.65  NaN
#
# [3788 rows x 11 columns]

# %% [markdown]
# 我有如图的数据表，其中：
# * trade_date : 日期
# * p_a_adj : 股票对应日期的A股的复权前复权价格
# * p_hk_adj : 股票对应日期的H股的复权前复权价格
# * hk2cn : 当日的港币兑人民币汇率（1港币可以换多少人民币）
# * AH_premium_adj : A股相对于H股当日的溢价
#
# 我希望构建一个基于AH溢价的选股策略：
# * 首先帮我写一个函数：
#     * 其参数是日期
#     * 输出是两个 list ，一个list是AH溢价最高的5支股票名字，一个是AH溢价最低的5支股票名字
# * 以及一个交易策略回测函数：
#     * 待定参数是策略周期:X个月
#     * 每个周期一开始把手上的钱均分成10份，其中5份对应平均购买那5支AH溢价最高的股票的H股，另外5份平均购买AH溢价最低的股票的A股
#     * 每个周期结束后进入下一个周期，用同样策略重新配置仓位
#     * 考虑资金量和交易成本（H股交易双向都按0.05%计算，A股交易双向都按0.01%计算，几个值都用变量来配置）
# * 分别绘制出策略周期X为1个月、2个月、3个月、6个月情况下的策略收益曲线，从2018年开始模拟

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# ———— 配置中文字体 & 负号 ————
matplotlib.rcParams["font.sans-serif"] = ["Microsoft YaHei", "SimHei"]
matplotlib.rcParams["axes.unicode_minus"] = False


def get_top_bottom(
    ah_df: pd.DataFrame, date: str | pd.Timestamp, top_n: int = 5
) -> tuple[list[str], list[str]]:
    """返回指定交易日 date 当天 AH 溢价最高和最低的股票名称列表。"""
    df = ah_df.copy()
    # 转 datetime
    if df["trade_date"].dtype == object or np.issubdtype(
        df["trade_date"].dtype, np.number
    ):
        df["trade_date"] = pd.to_datetime(df["trade_date"].astype(str), format="%Y%m%d")
    if isinstance(date, str):
        date = pd.to_datetime(date, format="%Y%m%d")
    today = df[df["trade_date"] == date].dropna(subset=["AH_premium_adj"])
    top5 = today.nlargest(top_n, "AH_premium_adj")["name"].tolist()
    bottom5 = today.nsmallest(top_n, "AH_premium_adj")["name"].tolist()
    return top5, bottom5

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# ———— 配置中文字体 & 负号 ————
matplotlib.rcParams["font.sans-serif"] = ["Microsoft YaHei", "SimHei"]
matplotlib.rcParams["axes.unicode_minus"] = False


def get_top_bottom(
    ah_df: pd.DataFrame, date: str | pd.Timestamp, top_n: int = 5
) -> tuple[list[str], list[str]]:
    """返回指定交易日 date 当天 AH 溢价最高和最低的股票名称列表。"""
    df = ah_df.copy()
    # 转 datetime
    if df["trade_date"].dtype == object or np.issubdtype(
        df["trade_date"].dtype, np.number
    ):
        df["trade_date"] = pd.to_datetime(df["trade_date"].astype(str), format="%Y%m%d")
    if isinstance(date, str):
        date = pd.to_datetime(date, format="%Y%m%d")
    today = df[df["trade_date"] == date].dropna(subset=["AH_premium_adj"])
    top5 = today.nlargest(top_n, "AH_premium_adj")["name"].tolist()
    bottom5 = today.nsmallest(top_n, "AH_premium_adj")["name"].tolist()
    return top5, bottom5

# %%
def backtest_ah_strategy(
    ah_df: pd.DataFrame,
    start_date: str = "20180101",
    months: int = 1,
    initial_capital: float = 1.0,
) -> pd.DataFrame:
    """
    AH 溢价轮动回测（离散周期估值），返回每期末的净值曲线。
    """
    df = ah_df.copy()
    df["trade_date"] = pd.to_datetime(df["trade_date"].astype(str), format="%Y%m%d")
    df = df.sort_values("trade_date")
    df["ph_cny"] = df["p_hk_adj"] * df["hk2cn"]

    # 所有可交易日
    dates = df["trade_date"].drop_duplicates().sort_values()
    dates = dates[dates >= pd.to_datetime(start_date, format="%Y%m%d")]
    if dates.empty:
        raise ValueError("start_date 之后没有数据")

    # 构造周期起始/结束列表
    period_starts = []
    cur = dates.min()
    last = dates.max()
    while cur <= last:
        ps = dates[dates >= cur].min()
        period_starts.append(ps)
        cur = ps + pd.DateOffset(months=months)
    period_starts = [d for d in period_starts if d <= last]

    period_ends = []
    for i in range(len(period_starts) - 1):
        nxt = period_starts[i + 1]
        pe = dates[dates < nxt].max()
        period_ends.append(pe)
    period_ends.append(last)

    capital = initial_capital
    records = []
    for ps, pe in zip(period_starts, period_ends):
        # 选股
        df_ps = df[df["trade_date"] == ps]
        top5, bot5 = get_top_bottom(df_ps, ps, top_n=5)
        alloc = capital / 10

        # 买入份额
        buy_ps = df_ps.set_index("name")
        shares_top = alloc / buy_ps.loc[top5, "ph_cny"]
        shares_bot = alloc / buy_ps.loc[bot5, "p_a_adj"]

        # 平仓：取 <= pe 时每只股票最后一条价格
        df_end = (
            df[df["trade_date"] <= pe]
            .sort_values("trade_date")
            .groupby("name", as_index=True)
            .last()
        )
        p_top = df_end["ph_cny"].reindex(top5).fillna(0)
        p_bot = df_end["p_a_adj"].reindex(bot5).fillna(0)

        val_top = (shares_top.values * p_top.values).sum()
        val_bot = (shares_bot.values * p_bot.values).sum()
        capital = val_top + val_bot

        records.append({"date": pe, "equity": capital})

    return pd.DataFrame(records)

# %%
if __name__ == "__main__":
    # —— 0. 设置 —— #
    start_dt_str = "20180101"
    start_dt = pd.to_datetime(start_dt_str, format="%Y%m%d")
    initial_capital = 1_000_000
    # —— 1. 读数据 —— #
    ah_k = pd.read_csv("data/AH_premium_analysis.csv", encoding="utf-8-sig")
    SH300_k = pd.read_csv("data/SH300_daily_k.csv", encoding="utf-8-sig")
    HSI_k = pd.read_csv("data/HSI_daily_k.csv", encoding="utf-8-sig")

    # —— 2. 准备指数归一化序列 —— #
    for idx_df in (SH300_k, HSI_k):
        idx_df["trade_date"] = pd.to_datetime(
            idx_df["trade_date"].astype(str), format="%Y%m%d"
        )
    sh300 = (
        SH300_k[SH300_k["trade_date"] >= start_dt]
        .sort_values("trade_date")
        .set_index("trade_date")
    )
    hsi = (
        HSI_k[HSI_k["trade_date"] >= start_dt]
        .sort_values("trade_date")
        .set_index("trade_date")
    )
    sh300["norm"] = sh300["close"] / sh300["close"].iloc[0]
    hsi["norm"] = hsi["close"] / hsi["close"].iloc[0]

    # —— 3. 回测并绘图 —— #
    plt.figure(figsize=(12, 6))

    # 3.1 画指数
    plt.plot(sh300.index, sh300["norm"], label="沪深300 指数", linewidth=1.2)
    plt.plot(hsi.index, hsi["norm"], label="恒生指数", linewidth=1.2)

    # 3.2 画策略（1、2、3、6 个月）
    for m in [1, 2, 3, 6]:
        eq = backtest_ah_strategy(ah_k, start_date=start_dt_str, months=m)
        plt.plot(
            eq["date"],
            eq["equity"],
            label=f"{m} 个月轮动策略",
            linestyle="--",
            marker="o",
        )

    plt.title(f"AH 溢价策略 vs. 两大指数（{start_dt_str} 起归一化）")
    plt.xlabel("日期")
    plt.ylabel("归一化收益（基准=1）")
    plt.legend(loc="upper left", fontsize=9)
    plt.grid(True)

    # —— 关键：让 y 轴从 0 开始 —— #
    plt.ylim(bottom=0)

    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 28
#      17 sh300 = (
#      18     SH300_k[SH300_k["trade_date"] >= start_dt]
#      19     .sort_values("trade_date")
#      20     .set_index("trade_date")
#      21 )
#      22 hsi = (
#      23     HSI_k[HSI_k["trade_date"] >= start_dt]
#      24     .sort_values("trade_date")
#      25     .set_index("trade_date")
#      26 )
#      27 ixic = (
# ---> 28     IXIC_k[IXIC_k["trade_date"] >= start_dt]
#      29     .sort_values("trade_date")
#      30     .set_index("trade_date")
#      31 )
#      32 sh300["norm"] = sh300["close"] / sh300["close"].iloc[0]
#      33 hsi["norm"] = hsi["close"] / hsi["close"].iloc[0]
#
# File d:\ProgramData\Anaconda3\envs\py310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File d:\ProgramData\Anaconda3\envs\py310\lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File d:\ProgramData\Anaconda3\envs\py310\lib\site-packages\pandas\core\series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File d:\ProgramData\Anaconda3\envs\py310\lib\site-packages\pandas\core\ops\array_ops.py:330, in comparison_op(left, right, op)
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# TypeError: '>=' not supported between instances of 'numpy.ndarray' and 'Timestamp'

# %% [markdown]
# # 策略执行

# %%
# 假设前面已经定义了 get_top_bottom()，并且 ah_k 已经读取完毕

# 指定想要查询的日期
query_date = "20250703"

# 调用函数
top5, bot5 = get_top_bottom(ah_k, query_date, top_n=5)

# 输出结果
print(f"{query_date} AH 溢价最高的 5 支：\n", top5)
print(f"{query_date} AH 溢价最低的 5 支：\n", bot5)
# Out:
# 20250703 AH 溢价最高的 5 支：
#  ['弘业期货', '复旦张江', '凯盛新能', '上海电气', '广汽集团']
# 20250703 AH 溢价最低的 5 支：
#  ['中国联通', '中国重汽', '宁德时代', '招商银行', '药明康德']
